# %%
import json
from tqdm.notebook import tqdm
from user_info import get_user_info
import random
from datetime import datetime
from dateutil.parser import parse

# %%
with open('../custom_data/jan_relevant_users_llm_output.json','rb') as f:
    resp = json.load(f)

# %%
uid_list = list(resp.keys())

# %%
def parse_user_work_ex(info_json):
    work_ex = []
    try:
        for x in info_json['professional_info'][0]:
            
            user_dict = {}
            exp_dict = x
        
            keys = ['id','designation','fromExpMonth','fromExpYear','toExpMonth','toExpYear'] 
        
            for k in keys:
                user_dict[k] = exp_dict[k]
                
            user_dict['company'] = exp_dict['organization']['name']
            work_ex.append(user_dict)
    except:
        return work_ex
            
    return work_ex

# %%
check = {}
for uid in tqdm(uid_list):
    info_json = get_user_info(uid)
    work_ex = parse_user_work_ex(info_json)
    check[uid] = work_ex
# Out:
#   0%|          | 0/16990 [00:00<?, ?it/s]

# %%
uid = random.sample(uid_list,1)[0]

# %%
check[uid]
# Out:
# [{'id': 136760,
#   'designation': 'Business development',
#   'fromExpMonth': '1',
#   'fromExpYear': '2017',
#   'toExpMonth': '0',
#   'toExpYear': '0',
#   'company': 'Grupo kaybee'}]

# %%
type(resp[uid])==list
# Out:
# True

# %%
excess = []
for userid in tqdm(uid_list):
    if isinstance(resp[userid], list):
        try:
            if len(resp[userid])>len(check[userid]):
                excess.append(userid)
        except Exception as e:
            print(resp[userid])
            print(e)
            continue
    else:
        continue
# Out:
#   0%|          | 0/16990 [00:00<?, ?it/s]

# %%
len(excess)
# Out:
# 7463

# %%
uid = random.sample(excess,1)[0]

# %%
check[uid]
# Out:
# [{'id': 2177939,
#   'designation': 'Sr. HR Executive',
#   'fromExpMonth': '7',
#   'fromExpYear': '2019',
#   'toExpMonth': '0',
#   'toExpYear': '0',
#   'company': 'Croma Campus'}]

# %%
resp[uid]
# Out:
# [{'company': 'KPMG Global Services',
#   'role': 'Senior Executive',
#   'start_date': 'Sep 2022',
#   'end_date': 'Present'},
#  {'company': 'ISHIR',
#   'role': 'Talent Acquisition Executive',
#   'start_date': 'Feb 2021',
#   'end_date': 'Sep 2022'},
#  {'company': 'SDG Software Pvt. Ltd.',
#   'role': 'Associate - HR',
#   'start_date': 'Aug 2019',
#   'end_date': 'Feb 2021'},
#  {'company': 'Talent Niti Recruitment Services Pvt. Ltd.',
#   'role': 'Talent Acquisition Specialist',
#   'start_date': 'Feb 2018',
#   'end_date': 'Jul 2019'}]

# %%
uid_checks = {}

for uid in tqdm(excess):
    es_jobs = []
    for idx, es_wex in enumerate(check[uid]):
        month = int(es_wex['fromExpMonth'])
        year = int(es_wex['fromExpYear'])
        start_time = datetime(year, month,1)
        es_jobs.append(start_time)

    try:
        comp = max(es_jobs)
    except:
        continue

    llm_exp = []
    for idx, llm_wex in enumerate(resp[uid]):
        try:
            start_time = parse(llm_wex['start_date'])
            if start_time>comp:
                if uid in uid_checks:
                    uid_checks[uid].append(llm_wex)
                else:
                    uid_checks[uid] = list()
                    uid_checks[uid].append(llm_wex)
        except Exception as e:
            print(e)
            pass
# Out:
#   0%|          | 0/7463 [00:00<?, ?it/s]
# Unknown string format: From July 2023
# Unknown string format: From December 2017
# Unknown string format: From April 2013
# Unknown string format: From Jul08
# Unknown string format: 1ST NOVEMlER 2021
# Unknown string format: OCTOlER 2011
# Unknown string format: CECEMlER 2009
# Unknown string format: 1ST SEPTEMlER 2009
# Unknown string format: After Graduation
# day is out of range for month: Mar00
# day is out of range for month: Mar00
# 'start_date'
# 'start_date'
# 'start_date'
# 'start_date'
# 'start_date'
# 'start_date'
# 'start_date'
# 'start_date'
# day is out of range for month: June00
# Unknown string format: Sep 20-Current
# Unknown string format: Sep 20-Current
# Unknown string format: Sep 20-Current
# Unknown string format: Sep 20-Current
# Unknown string format: ay 2010
# Unknown string format: 2003-2005
# Unknown string format: January - November 1997
# Unknown string format: Noida: 22 June 2010
# day is out of range for month: Aug 00
# Unknown string format: Aug 2K
# 'start_date'
# 'start_date'
# 'start_date'
# 'start_date'
# 'start_date'
# 'start_date'
# 'start_date'
# Unknown string format: Mar21Mar23
# Unknown string format: Jun06Feb08
# Unknown string format: Jan17Mar19
# Unknown string format: Apr11Jun16
# Unknown string format: NA
# Unknown string format: NA
# Unknown string format: NA
# Unknown string format: NA
# Unknown string format: NA
# Unknown string format: April21 Onwards
# Unknown string format: Oct19  Mar21
# Unknown string format: April17  Sep18
# Unknown string format: Feb15  Aug15
# Unknown string format: May13 - Jan15
# Unknown string format: Jui 23  Tiii Drte
# Unknown string format: Aprii 19
# Unknown string format: Jui 15
# Unknown string format: Mr 11
# Unknown string format: Jan 12- Feb 12
# Unknown string format: New Delhi-02/2021
# Unknown string format: Bangalore, Karnataka
# Unknown string format: Hyderabad, Telangana
# Unknown string format: Chalakudy, Kerala
# Unknown string format: May13-Oct14
# Unknown string format: July11-Apr12
# Unknown string format: Oct10-Jun11
# Unknown string format: May09-Aug10
# Unknown string format: Currently working
# Unknown string format: Duration: 1 year
# Unknown string format: Current
# Unknown string format: Lead the insurance consulting, data analytics and research business with the key responsibilities of (1) Service Delivery, (2) Stakeholder Management and (3) Team Management
# day is out of range for month: Jan 00
# Unknown string format: Octobir 2021
# Unknown string format: Fibruary 2017
# Unknown string format: Sep20 Now
# Unknown string format: Aug18  Aug20
# Unknown string format: Aug14  Aug18
# Unknown string format: Oct12  July14
# Unknown string format: Aug11  Oct12
# Unknown string format: Jul08  Jun09
# Unknown string format: Apr  May 10
# Unknown string format: 2000 & 2002
# Unknown string format: Present
# Unknown string format: 2022-07-
# Unknown string format: 2021-11-
# Unknown string format: 2016-11-
# Unknown string format: 2016-10-
# Unknown string format: 2013-11-
# Unknown string format: 2011-08-
# Unknown string format: 2010-2012
# Unknown string format: 2004-2007
# Unknown string format: 2003-2004
# Unknown string format: 2001-2002
# day is out of range for month: Jun00
# Unknown string format: Bhartiya Vidyapeeth
# Unknown string format: ALSO
# Unknown string format: ALSO
# Unknown string format: ALSO
# Unknown string format: ALSO
# day is out of range for month: Feb 00
# Unknown string format: 26 Months
# Unknown string format: Summer Internship
# Unknown string format: Airtel Karnataka The Flagship Circle
# Unknown string format: Corp HQ  Gurgaon
# day is out of range for month: Mar 00
# Unknown string format: Mfy 2004
# Unknown string format: 1 year 2 months
# Unknown string format: 2 years
# Unknown string format: 11 months
# Unknown string format: 2 years
# Unknown string format: 2 years
# Unknown string format: 2020-2021
# Unknown string format: 2012-2015
# Unknown string format: 2012-2015
# Unknown string format: 2011-2012
# Unknown string format: 2011-2012
# Unknown string format: 2004-2007
# Unknown string format: 2004-2007
# day is out of range for month: Apr'00
# day is out of range for month: Apr'00
# day is out of range for month: Apr'00
# 'start_date'
# 'start_date'
# 'start_date'
# 'start_date'
# day is out of range for month: May00
# 'start_date'
# 'start_date'
# 'start_date'
# 'start_date'
# 'start_date'
# Unknown string format: Apr-May 2011
# Unknown string format: Delhi
# Unknown string format: Delhi
# Unknown string format: 10 Months
# Unknown string format: 8 Months
# Unknown string format: 8 Months
# Unknown string format: 30 Months
# Unknown string format: 12 Months
# Unknown string format: 6 Months
# Unknown string format: 12 Months
# Unknown string format: 2018-2019
# Unknown string format: 2004-2007
# Unknown string format: 2004-2007
# Unknown string format: May-July13
# Unknown string format: Performed and managed product-line(s) gap analysis leading to the strategic introduction of a tiered, best-in-class, product positioning strategy to channel for Littles  baby care brand. Crafted short- and long-term brand strategies that identified product holes, new markets, and messaging strategies.
# Unknown string format: Developed the marketing mix and business plans for the nation-wide rollout of new products.
# Unknown string format: Led the Gala NO DUST broom from the germ of an idea to a successful launch.
# 'start_date'
# Unknown string format: March(10 12)
# 'start_date'
# 'start_date'
# 'start_date'
# 'start_date'
# 'start_date'
# 'start_date'
# 'start_date'
# Unknown string format: Since Jan 21
# Unknown string format: Amity Univ, Noida, 2006
# Unknown string format: Jan-March07
# Unknown string format: Dec05-Jan07
# Unknown string format: Sep 04-Nov 05
# Unknown string format: April 01- Dec 03
# Unknown string format: September 98- March 01
# Unknown string format: Feb 93-Dec 95
# Unknown string format: Feb 93-Dec 95
# Unknown string format: Seasoned Human Resource Professional with standout experience of over 22 years in Human Resources, creating and continuously improving HR processes focused on corporate and employee success, recognized for meticulous decisive processes prowess that leads to sustained growth. A distinction in directing holistic HR functions & aligning the key components that underpin successful business-driven HR advantage.
# year 20012 is out of range: May 20012
# Unknown string format: Currently
# Unknown string format: Summer 2011
# Unknown string format: Ocober 2022
# Unknown string format: Dec `11
# Unknown string format: April `07
# Unknown string format: September `99
# Unknown string format: July `96
# Unknown string format: July `96
# Unknown string format: Defence Colony, Sainikpuri, Secunderabad
# 'start_date'
# 'start_date'
# 'start_date'
# 'start_date'
# 'start_date'
# 'start_date'
# string indices must be integers
# string indices must be integers
# string indices must be integers
# string indices must be integers
# string indices must be integers
# string indices must be integers
# string indices must be integers
# string indices must be integers
# string indices must be integers
# string indices must be integers
# string indices must be integers
# string indices must be integers
# string indices must be integers
# string indices must be integers
# string indices must be integers
# string indices must be integers
# string indices must be integers
# string indices must be integers
# string indices must be integers
# string indices must be integers
# 'start_date'
# Unknown string format: 11thSept 08
# Unknown string format: 20thFeb 06
# Unknown string format: 5thMay-04
# Unknown string format: Apr 21  Present
# Unknown string format: April 19 - March 21
# Unknown string format: April 18- March 19
# Unknown string format: April 17 - March 18
# Unknown string format: Nov 14  Aug 15
# Unknown string format: Mar 13  Aug 15
# Unknown string format: Noi08
# Unknown string format: Def 22
# Unknown string format: Oft19
# Unknown string format: Oft19
# Unknown string format: Jan 21  Present
# Unknown string format: Oct 15  Dec 2020
# Unknown string format: Apr to Nov 2011
# day is out of range for month: Apr00
# day is out of range for month: Feb 00
# day is out of range for month: Apr 00
# Unknown string format: Set-up HR capability for a newly incorporated global development center in Mumbai
# Unknown string format: Streamline the merchant service contact center for the business to support the sales strategy
# Unknown string format: Basic HR start up kit
# day is out of range for month: Feb.00
# day is out of range for month: Feb.00
# Unknown string format: 8+ years ago
# Unknown string format: 8 years ago
# Unknown string format: 8 years ago
# Unknown string format: 8 years ago
# Unknown string format: 8 years ago
# Unknown string format: 6+ years ago
# Unknown string format: 6+ years ago
# Unknown string format: 6+ years ago
# Unknown string format: 6+ years ago
# Unknown string format: 6+ years ago
# Unknown string format: 6+ years ago
# Unknown string format: 6+ years ago
# Unknown string format: 6+ years ago
# Unknown string format: Since Mar12
# Unknown string format: Bangalore
# Unknown string format: Bangalore
# Unknown string format: Sertember 2008
# Unknown string format: Arril 2004
# Unknown string format: Apr-June, 2007
# Unknown string format: May-July, 2004
# Unknown string format: May-July, 2003
# Unknown string format: Dec-13-Till date
# day is out of range for month: May00
# Unknown string format: Mar20  Jun22
# Unknown string format: Jan17  Jan20
# Unknown string format: Sep14  Dec16
# Unknown string format: Mar13  Aug14
# Unknown string format: May10  Feb13
# Unknown string format: Jan06  Apr10
# Unknown string format: Jan03  Dec05
# Unknown string format: Fe2 2014
# day is out of range for month: May 98 2000
# Unknown string format: Mumbai (2012)
# Unknown string format: San Jose, USA (2009)
# Unknown string format: 2007-2009
# Unknown string format: Part time
# Unknown string format: Jan 200- Feb 2004
# day is out of range for month: Jun 00
# bad month number 21; must be 1-12: 2020-21
# Unknown string format: Basis
# Unknown string format: Mumbai Analytics Centre, Global Institution Risk Management
# Unknown string format: APRIL-JUNE, 2012
# Unknown string format: Since Aug09
# day is out of range for month: Jul00
# day is out of range for month: Apr00
# Unknown string format: 2015-2016
# Unknown string format: 2013-2015
# Unknown string format: 2011-2013
# Unknown string format: 2007-2011
# Unknown string format: 2003-2007
# Unknown string format: 2001-2003
# day is out of range for month: Nov 95, 2006
# 'start_date'
# Unknown string format: Total 20+ yrs.
# Unknown string format: 5 years
# Unknown string format: 1 year
# Unknown string format: 4.6 years
# Unknown string format: Post Graduate Diploma: Sales &Advertising Management ,M.S.University, Vadodara
# Unknown string format: Winter 2004
# Unknown string format: Current
# Unknown string format: Giving sales propositions to the client for making purchases of 3G enabled ZTE equipments
# Unknown string format: Aircall Teleservices
# Unknown string format: Graduate in Electronics & Telecommunication with 7 CGPA
# Unknown string format: Gujarat
# Unknown string format: Orissa
# Unknown string format: Orissa
# Unknown string format: Mr 12-Aug13
# 'start_date'
# 'start_date'
# 'start_date'
# 'start_date'
# 'start_date'
# 'start_date'
# 'start_date'
# 'start_date'
# 'start_date'
# 'start_date'
# 'start_date'
# 'start_date'
# 'start_date'
# 'start_date'
# 'start_date'
# 'start_date'
# 'start_date'
# Unknown string format: May -2011-June-2014
# Unknown string format: 2009-2011
# Unknown string format: 2006 - 2009
# Unknown string format: Mar 20-Apr 21
# Unknown string format: Mar 20-Apr 21
# Unknown string format: Aug 14-Feb 20
# Unknown string format: Sep 11-Aug 14
# Unknown string format: Apr 10-Aug 11
# Unknown string format: Apr 00-Dec 04
# Unknown string format: Apr 00-Dec 04
# Unknown string format: Core HR
# Unknown string format: Current
# day is out of range for month: Aug 00
# 'start_date'
# 'start_date'
# 'start_date'
# 'start_date'
# 'start_date'
# 'start_date'
# 'start_date'
# 'start_date'
# 'start_date'
# Unknown string format: Apr-May 2008
# Unknown string format: 2 Months
# Unknown string format: 2 Months
# Unknown string format: 2 Months
# Unknown string format: Jan 22  Ongoing
# Unknown string format: Jun16  Jan 22
# Unknown string format: May14  Jun16
# Unknown string format: Apr10  June12
# Unknown string format: April13  May13
# Unknown string format: Ph.D
# Unknown string format: GITAM University
# Unknown string format: Andhra University
# 'start_date'
# 'start_date'
# 'start_date'
# 'start_date'
# 'start_date'
# Unknown string format: Apl 2013
# Unknown string format: FY 13
# Unknown string format: FY 07
# day is out of range for month: Aug 00
# Unknown string format: Apl 2006
# Unknown string format: Business Analysis and Marketing Research for a Healthcare Company
# Unknown string format: Mar Onwards
# Unknown string format: July 12  Aug18
# Unknown string format: Cliena 2
# Unknown string format: Duration: Summer Training (8 Weeks)
# Unknown string format: Since 8th December 2021
# Unknown string format: Since May 2018
# Unknown string format: Since June 2015
# 'start_date'
# 'start_date'
# 'start_date'
# 'start_date'
# 'start_date'
# 'start_date'
# Unknown string format: Sept`21
# Unknown string format: Aug`20
# Unknown string format: Aug`19
# Unknown string format: Oct`18
# Unknown string format: Jun`13
# Unknown string format: Jul`15
# Unknown string format: Jul`14
# Unknown string format: Jun`10
# Unknown string format: Summer 2012
# Unknown string format: May’09
# Unknown string format: Since 2006
# 'start_date'
# 'start_date'
# 'start_date'
# 'start_date'
# 'start_date'
# 'start_date'
# 'start_date'
# 'start_date'
# 'start_date'
# 'start_date'
# 'start_date'
# 'start_date'
# Unknown string format: 2 Months
# Unknown string format: Jly 1991
# Unknown string format: Jly 1992
# Unknown string format: Certification in Digital Marketing. Certification in Google Analytics, SEO, SEM.
# 'start_date'
# 'start_date'
# 'start_date'
# 'start_date'
# 'start_date'
# 'start_date'
# 'start_date'
# 'start_date'
# 'start_date'
# Unknown string format: May-Aug 2014
# Unknown string format: Apr-Jun 2013
# Unknown string format: Jun-Dec 2011
# Unknown string format: Jnne 2023
# Unknown string format: Jannary 2020
# Unknown string format: Jnne 13
# Unknown string format: Jnne 05
# Unknown string format: Jannary 2020
# Unknown string format: Present
# Unknown string format: Training on PMI-Project Management from Astrowix
# Unknown string format: From Nov 2010-Mar 2012
# Unknown string format: From Nov 2010-Mar 2012
# day is out of range for month: Apr 96 2000
# Unknown string format: 09 Months
# Unknown string format: 03 Yrs 11 months
# Unknown string format: 11 Yrs 3 Months
# Unknown string format: N/A
# Unknown string format: N/A
# Unknown string format: N/A
# Unknown string format: N/A
# Unknown string format: N/A
# day is out of range for month: Jul00
# Unknown string format: 2021 Aug  present
# 'start_date'
# 'start_date'
# 'start_date'
# 'start_date'
# 'start_date'
# 'start_date'
# Unknown string format: Responsibilities:
# Unknown string format: Responsibilities:
# Unknown string format: Responsibilities:
# Unknown string format: April-June 2013
# bad month number 14; must be 1-12: 2013-14
# bad month number 14; must be 1-12: 2013-14
# Unknown string format: Dec’14
# Unknown string format: Apr’01
# Unknown string format: Jan’06
# Unknown string format: Apr’01
# Unknown string format: Jan’99
# Unknown string format: 2005-2007
# Unknown string format: 2002-2005
# Unknown string format: SEP TEMB ER 2019
# Unknown string format: FEBR UAR Y 2009
# Unknown string format: May-June 2012
# Unknown string format: November-December 2011
# Unknown string format: May 2010-June 2010
# Unknown string format: May-June 2009
# Unknown string format: November-December 2008
# Unknown string format: Augs 2016
# Unknown string format: Year 2007-2009
# Unknown string format: Year 2004-2005
# Unknown string format: Year 2000-2003
# day is out of range for month: Oct00
# Unknown string format: TNA: Conduct programs as per the business requirement of the circles month on month. Driving the key business levers - Quarterly or ad hoc need. Publish monthly and quarterly training calendars, dashboards of coverage and dashboards of training effectiveness circle and region wise
# Unknown string format: Develop and Mentor the Training Managers, generate and publish Training Calendar, MIS and Dashboard for the cluster
# Unknown string format: Completed initial project training for COCOS, DODOS, CODOS and COFOS of Retail Automation Project through ROSS in phase-1 and through RETALIX in phase-2
# Unknown string format: To manage the day-to-day functions of 6 retail outlets in the zone, manage sales, supplies and logistics
# Unknown string format: Ensuring achievement of team target. Recruiting and training of sales ocers. Sales and deliveries, conducting promotional activities, dealer management
# Unknown string format: 9yrs
# Unknown string format: 5yrs
# Unknown string format: 14+ yrs. of experience in Credit, Liability Risk (Kyc/Aml/Compliance), Banking Operation, & Operational Risk/ / Micro Finance
# day is out of range for month: Jun 00
# Unknown string format: Summer Internship Program
# Unknown string format: Def 14 2014
# day is out of range for month: Aug 00 2000
# Unknown string format: Oft 97 1997
# day is out of range for month: Sep 96 1996
# day is out of range for month: Jul 00 1996
# 'start_date'
# 'start_date'
# 'start_date'
# 'start_date'
# 'start_date'
# 'start_date'
# 'start_date'
# 'start_date'
# 'start_date'
# Unknown string format: 1+Year
# Unknown string format: 1 Year
# Unknown string format: 2 Years
# Unknown string format: 6 Years
# Unknown string format: 2 Years
# Unknown string format: 6 Months
# Unknown string format: present
# Unknown string format: 2018 Feb 2022
# Unknown string format: 2005 October-2008Jan.
# Unknown string format: Present
# Unknown string format: 2011 Jan 2015 Oct
# Unknown string format: June 06 To April 07
# 'start_date'
# 'start_date'
# 'start_date'
# 'start_date'
# 'start_date'
# 'start_date'
# Unknown string format: Sep12-Oct13
# Unknown string format: Apr06Nov06
# Unknown string format: Oct01- Feb04
# Unknown string format: May00-Aug01
# Unknown string format: May00-Aug01
# day is out of range for month: Jun 00
# Unknown string format: Moodys Analytics (Acuity)
# Unknown string format: Technology Research
# Unknown string format: Lead cross functional project of relocating premium brand supply chain to India as part of leadership team resulting in to product wise margin improvement by 20% & inventory reduction by 45 days
# 'start_date'
# 'start_date'
# 'start_date'
# 'start_date'
# 'start_date'
# 'start_date'
# 'start_date'
# 'start_date'
# 'start_date'
# 'start_date'
# 'start_date'
# 'start_date'
# 'start_date'
# 'start_date'
# 'start_date'
# 'start_date'
# 'start_date'
# 'start_date'
# 'start_date'
# Unknown string format: Present
# Unknown string format: Summer Internship
# Unknown string format: Present
# Unknown string format: semester 1998-99
# Unknown string format: Auguet 2019
# Unknown string format: Sestember 2017
# Unknown string format: 13+ years ago
# Unknown string format: New Delhi
# Unknown string format: Lucknow
# Unknown string format: on the payrolls of HCL Infosystems Ltd.
# Unknown string format: 13+ years ago
# Unknown string format: 13+ years ago
# Unknown string format: January 07 to May-15
# Unknown string format: Oca 1998
# day is out of range for month: Aug00
# Unknown string format: Oca20
# Unknown string format: Jao19
# Unknown string format: Juoe18
# Unknown string format: Juoe18
# Unknown string format: Juoe18
# Unknown string format: Juo12
# Unknown string format: May20-Now
# Unknown string format: Apr17- May7
# Unknown string format: June13  Aug15
# Unknown string format: June13  Aug15
# Unknown string format: M A 2 0 2 2 3 P Q E S E N T
# Unknown string format: M A QC H 2 0 1 6 3 M A QC H 2 0 1 8
# Unknown string format: N OV E M B E Q 2 0 1 5 3 F E B QZA Q  2 0 1 6
# day is out of range for month: 07/00
# day is out of range for month: Dec00
# Unknown string format: 5 Years
# Unknown string format: Ongoing
# day is out of range for month: Sep 00
# Unknown string format: AUG US T 2016
# Unknown string format: SEP TEMB ER 2015
# 'start_date'
# Unknown string format: May 23  Present
# Unknown string format: Aug 21  May23
# Unknown string format: Dec 19  Dec 20
# Unknown string format: Dec 17  Nov 19
# Unknown string format: Sep 17  Dec 17
# Unknown string format: May 16  Aug 17
# Unknown string format: Mar 15  Apr 16
# Unknown string format: May 14  Mar 15
# Unknown string format: Marih 2023
# Unknown string format: Deiember 2017
# Unknown string format: Deiember 2012
# Unknown string format: Oit 2005
# Unknown string format: NA
# day is out of range for month: Nov00
# Unknown string format: Year 2001- Year 2006
# day is out of range for month: Sep 00
# day is out of range for month: Mar00
# Unknown string format: Jugn 2018
# 'start_date'
# 'start_date'
# 'start_date'
# 'start_date'
# 'start_date'
# 'start_date'
# 'start_date'
# Unknown string format: Brand building of Digital Assets, boosting sales through paid campaigns & re-engagement using SMS/Email Marketing/WhatsApp marketing
# Unknown string format: Working Part Time
# Unknown string format: Working Part Time
# Unknown string format: Jul: 2013
# Unknown string format: Apr - Jun 2013
# 'start_date'
# year 20017 is out of range: 20017
# 'start_date'
# 'start_date'
# 'start_date'
# 'start_date'
# 'start_date'
# 'start_date'
# 'start_date'
# 'start_date'
# Unknown string format: Pune
# Unknown string format: Negotiations and closure of indirect or services procurement of value of Rs 30. Crores
# Unknown string format: Heading an ecosystem of 300+ sewing schools across the country, for training students in garment construction, patternmaking, designing and certifying upwards of 8,500 students every year
# Unknown string format: Responsible for income generation for 10,000+ village level entrepreneurs through sales of socially relevant product categories which have a sustainable impact on key issues such as female and child nutrition and sanitation, renewable energy, indoor air pollution, education for children and personal hygiene, to name a few
# Unknown string format: Part of the Corporate Solutions Group, and responsible for generating revenue from General Insurance policies from Corporates (>30 Cr Turnover) in Noida and Faridabad.
# Unknown string format: May23- Present
# Unknown string format: Nov22-Mar23
# Unknown string format: Dec21- Oct22
# Unknown string format: July21-Dec21
# Unknown string format: Dec17-May18
# Unknown string format: June 2017-Dec2017
# Unknown string format: May2015-June2017
# 'start_date'
# 'start_date'
# 'start_date'
# 'start_date'
# 'start_date'
# 'start_date'
# 'start_date'
# 'start_date'
# Unknown string format: 16 Feb 18 March 22
# Unknown string format: Since Feb 2020
# day is out of range for month: Sep00
# Unknown string format: 3 Years and 6 Months
# 'start_date'
# 'start_date'
# 'start_date'
# 'start_date'
# 'start_date'
# 'start_date'
# Unknown string format: Axr07
# Unknown string format: Till Date
# Unknown string format: Till Date
# Unknown string format: Oct11-Nov13
# Unknown string format: 6 months
# Unknown string format: 2 months
# Unknown string format: 1 month
# Unknown string format: Ma'17
# day is out of range for month: Oct'00
# Unknown string format: 2021-2023
# Unknown string format: 2006-2021
# Unknown string format: +91 9823217963
# Unknown string format: 2019-2021
# Unknown string format: 2018-2019
# Unknown string format: 2015-2018
# Unknown string format: 2015-2018
# Unknown string format: 14 years ago
# Unknown string format: 08 weeks
# Unknown string format: Modern Trade
# Unknown string format: Oct16- till date
# Unknown string format: April 15 to Sept16
# Unknown string format: April12 till March15
# Unknown string format: July10 to March12
# Unknown string format: July08 to June10
# Unknown string format: April05 to June08
# Unknown string format: June02 to March05
# Unknown string format: March 01 to June 02
# Unknown string format: August 98 to March 99
# day is out of range for month: Sep 00
# Unknown string format: Aprii 2004
# Unknown string format: April20- Oct21
# Unknown string format: Sept16- March2020
# Unknown string format: Feb12-June15
# Unknown string format: April20- Oct21
# month must be in 1..12: 13-14
# day is out of range for month: May 00
# Unknown string format: April-May 2014
# Unknown string format: General Corporate
# Unknown string format: April 22- May 23
# Unknown string format: April 20- March 22
# Unknown string format: Aug 23- Present
# Unknown string format: Since Dec 2018
# Unknown string format: Since June 2013
# 'start_date'
# 'start_date'
# 'start_date'
# Unknown string format: Not Specified
# Unknown string format: Not Specified
# Unknown string format: Orion May23
# Unknown string format: Digital Jul19
# Unknown string format: Aug20-Till Date
# Unknown string format: Present
# Unknown string format: 2020 Nov-2021 Jul
# Unknown string format: 2020 Aug-2021 Jul
# Unknown string format: 2014 Feb-2015 Aug
# Unknown string format: 2014 Feb-2015 Aug
# Unknown string format: 2018 June-2020 June
# Unknown string format: 2014 Feb-2015 Aug
# Unknown string format: 2014 Feb-2015 Aug
# Unknown string format: 2014 Feb-2015 Aug
# Unknown string format: 2014 Feb-2015 Aug
# Unknown string format: 2014 Feb-2015 Aug
# Unknown string format: 2014 Feb-2015 Aug
# Unknown string format: 2014 Feb-2015 Aug
# Unknown string format: Apr’13
# Unknown string format: Aug’10
# Unknown string format: March’09
# Unknown string format: July’05
# Unknown string format: Jul’03
# Unknown string format: Jun’01
# Unknown string format: Maximized the wholesalers penetration by 25% of premium products & increased the sales volume by 15%
# Unknown string format: Pursued a course in E-Prodigy (Website Designing) from ZAP INFOTECH Delhi
# Unknown string format: N/A
# Unknown string format: 2019- 2020
# Unknown string format: 2017-2019
# Unknown string format: 2010-2017
# Unknown string format: 2008-2010
# Unknown string format: 2006-2008
# Unknown string format: 1997-2001
# Unknown string format: 1996-2001
# Unknown string format: 1991-1995
# Unknown string format: 22 years ago
# Unknown string format: Sep1P-Dec14
# Unknown string format: Jarn15-Jarn17
# day is out of range for month: Jan 00
# 'start_date'
# 'start_date'
# 'start_date'
# 'start_date'
# 'start_date'
# 'start_date'
# 'start_date'
# 'start_date'
# day is out of range for month: Jan 00
# Unknown string format: Notable Accomplishment
# day is out of range for month: SEPT 00
# 'start_date'
# 'start_date'
# 'start_date'
# 'start_date'
# 'start_date'
# 'start_date'
# Unknown string format: Monitoring & help maintaining the reliability & customer experience metrics on real time basis for the shipments under the purview of a 1,50,000 Sq Ft warehouse and transport centre which processes about 6 lac shipments/day
# day is out of range for month: Dec00
# Unknown string format: NA
# Unknown string format: Current
# 'start_date'
# 'start_date'
# 'start_date'
# 'start_date'
# 'start_date'
# 'start_date'
# 'start_date'
# 'start_date'
# 'start_date'
# 'start_date'
# 'start_date'
# 'start_date'
# 'start_date'
# 'start_date'
# 'start_date'
# Unknown string format: Sept23  till date
# Unknown string format: Feb22  March23
# Unknown string format: Aug 2020  May21
# Unknown string format: Aug 2019  Apr 2020
# Unknown string format: Dec 2017  Aug 2019
# Unknown string format: Jun 2016 - Nov 2017
# Unknown string format: Apr 2014 - Jun 2016
# Unknown string format: Mar 2007 - Nov 2007
# Unknown string format: Mar 2006  Mar 2007
# Unknown string format: Sep 2002  Jun 2004
# Unknown string format: Jan 2001 Aug 2002
# Unknown string format: May 1997  Jan 2001
# Unknown string format: 15 Years 6 Months
# Unknown string format: Worked as Senior Manager with in SME Group in New Delhi.
# Unknown string format: Joined the Bank as Management Trainee.
# Unknown string format: ROLE
# day is out of range for month: May00
# Unknown string format: N/A
# Unknown string format: N/A
# Unknown string format: N/A
# day is out of range for month: Sep00
# Unknown string format: Since Apl20
# day is out of range for month: Feb00
# Unknown string format: 2021-2023
# Unknown string format: 2017-2020
# Unknown string format: 2006-2017
# Unknown string format: 1997-2006
# Unknown string format: 1991-1997
# Unknown string format: 1986-1991
# Unknown string format: 1980-1986
# Unknown string format: Certified
# Unknown string format: Certified
# Unknown string format: Certified
# Unknown string format: Certified
# Unknown string format: Certified
# Unknown string format: Sep’22
# Unknown string format: Jul’20
# Unknown string format: Apr’19
# Unknown string format: Oct’16
# Unknown string format: Jun’15
# Unknown string format: Manaeee
# Unknown string format: Winner of Microsoft secure wars Competition
# day is out of range for month: Jun 00
# day is out of range for month: Jun 00
# Unknown string format: Pune
# Unknown string format: Ma 18
# Unknown string format: Year 2001-2003
# day is out of range for month: Apr 00
# Unknown string format: Key Result Areas:
# Unknown string format: MM00
# Unknown string format: MM97
# Unknown string format: Fea13
# Unknown string format: Fea06
# Unknown string format: Fea06
# day is out of range for month: May 00
# Unknown string format: Jan20-till date
# Unknown string format: May 20  present
# Unknown string format: Dec 09  Feb 18
# Unknown string format: Aug 02  Dec 09
# Unknown string format: Apr 99 - Dec 00
# Unknown string format: 1996-1997
# Unknown string format: 1997-1998
# Unknown string format: 1995-1996
# Unknown string format: 8 weeks
# Unknown string format: NOV E M B E R 2 0 2 2
# Unknown string format: J U N E 2 0 2 1
# Unknown string format: SEP T E M B E R 2 0 1 9
# Unknown string format: SEP T E M B E R 2 0 1 8
# Unknown string format: N OV E M B E R 2 0 1 6
# Unknown string format: J U N E 2 0 1 4
# Unknown string format: May  June 12
# Unknown string format: Apr - May, 2015
# Unknown string format: May20-Present
# Unknown string format: May19-Apr20
# Unknown string format: Apr18-May18
# Unknown string format: Apr16-Jun17
# Unknown string format: July14-Dec15
# bad month number 14; must be 1-12: 2013-14
# bad month number 14; must be 1-12: 2013-14
# bad month number 13; must be 1-12: 2012-13
# Unknown string format: Jul,10- Jun,12
# Unknown string format: Feb,07- Oct,08
# Unknown string format: Oct,05- Nov,06
# Unknown string format: Aur '16
# Unknown string format: Jua '09
# Unknown string format: Alglst 2020
# Unknown string format: Febrlary 2014
# Unknown string format: Alglst 2013
# Unknown string format: Alglst 2012
# Unknown string format: Janlary 2007
# Unknown string format: Till Sep18
# day is out of range for month: Jun00
# Unknown string format: Decemeber10
# day is out of range for month: Aug 00
# Unknown string format: ~ 2 years
# Unknown string format: 3 years
# Unknown string format: 2 months
# Unknown string format: June - Dec 2010
# Unknown string format: MARKETING MANAGER-DIGITAL
# Unknown string format: TILL DATE
# day is out of range for month: Jun00
# Unknown string format: Apr-Sept 2004
# day is out of range for month: May, 00
# Unknown string format: June 22--- Present
# Unknown string format: Dec 2019  Feb 2021
# Unknown string format: Mar 2019  Dec 2019
# Unknown string format: Oct 2017  Mar 2019
# Unknown string format: Apr 2016  Sep 2016
# Unknown string format: Sep 2011  May 2012
# Unknown string format: Jan 2010  Aug 2010
# Unknown string format: Feb 2007  Dec 2007
# Unknown string format: July 2006  Jan 2007
# Unknown string format: June 2003  Jan 2005
# Unknown string format: June 1999  May 2000
# Unknown string format: Feb 1993  June 1995
# Unknown string format: Jan 1991  Dec 1991
# Unknown string format: Jan 1990  Dec 1990
# 'start_date'
# 'start_date'
# 'start_date'
# 'start_date'
# 'start_date'
# 'start_date'
# 'start_date'
# Unknown string format: Jrn21
# day is out of range for month: Apr00
# Unknown string format: Real Estate
# Unknown string format: From Fenb21
# Unknown string format: From July2020
# Unknown string format: From Dec 2018
# Unknown string format: From Dec 2017
# Unknown string format: From July 2015
# Unknown string format: From May 2012
# Unknown string format: Not in live
# Unknown string format: Present
# Unknown string format: Present
# Unknown string format: w nandaartcat.weebly.com
# 'start_date'
# 'start_date'
# 'start_date'
# 'start_date'
# 'start_date'
# 'start_date'
# 'start_date'
# 'start_date'
# 'start_date'
# 'start_date'
# 'start_date'
# 'start_date'
# 'start_date'
# 'start_date'
# Unknown string format: October to Apr 2023
# Unknown string format: O C TO B E R 2 0 2 2
# Unknown string format: 2012-Oct-
# Unknown string format: Aprii 2017
# 'start_date'
# 'start_date'
# 'start_date'
# 'start_date'
# 'start_date'
# 'start_date'
# 'start_date'
# 'start_date'
# 'start_date'
# 'start_date'
# 'start_date'
# 'start_date'
# 'start_date'
# 'start_date'
# 'start_date'
# Unknown string format: eb 2016
# Unknown string format: eb 2007
# Unknown string format: 2015 Jui 31st May
# day is out of range for month: Sep 00
# Unknown string format: Certification course on Electric Industry Operations and Markets offered by Duke University, The U.S.A
# Unknown string format: Certificate Id PWLUEDMQV8Y2
# Unknown string format: Certificate Id GE3JK234YLJX
# Unknown string format: On-boarded and managed key brands such as The Clothing Factory, Emprall, Beeglee, Rigo, Alter Ego etc
# Unknown string format: Since September 2018
# Unknown string format: Indian Institute of Finance, Delhi
# 'start_date'
# 'start_date'
# 'start_date'
# 'start_date'
# 'start_date'
# 'start_date'
# 'start_date'
# 'start_date'
# 'start_date'
# Unknown string format: 0.5 years ago
# Unknown string format: 0.5 years ago
# Unknown string format: 8 years ago
# Unknown string format: 3 years ago
# Unknown string format: 4 years ago
# Unknown string format: 4 years ago
# Unknown string format: Effective June 2017
# Unknown string format: Jan"07
# Unknown string format: Mar"06
# Unknown string format: Year 2002-2003
# Unknown string format: Year 2002-2003
# Unknown string format: Year 2001-2002
# day is out of range for month: Jul00
# Unknown string format: Summer Project
# Unknown string format: Oct- 2014
# day is out of range for month: Sep00
# Unknown string format: Arg. 2019
# Unknown string format: Arg. 2017
# Unknown string format: Jrn 2014
# Unknown string format: Arg 2012
# Unknown string format: RIL  Reliance Trends, TST, EXT & JNR
# Unknown string format: TST
# Unknown string format: EXT
# Unknown string format: JNR
# day is out of range for month: Dec 00
# Unknown string format: HOLT
# Unknown string format: July 22  till date
# Unknown string format: March 2018  July 2022
# Unknown string format: Apr 15  March 18
# Unknown string format: 2019-Present
# Unknown string format: March 2017-Oct 2019
# Unknown string format: March 2015-Dec 2016
# Unknown string format: Feb 2010-Feb 2015
# Unknown string format: Feb 2008-Jan 2010
# 'start_date'
# 'start_date'
# 'start_date'
# 'start_date'
# 'start_date'
# 'start_date'
# 'start_date'
# 'start_date'
# 'start_date'
# 'start_date'
# 'start_date'
# 'start_date'
# 'start_date'
# 'start_date'
# 'start_date'
# 'start_date'
# bad month number 18; must be 1-12: 2017-18
# day is out of range for month: Nov 00
# day is out of range for month: Nov 00
# day is out of range for month: Oct00
# Unknown string format: 2 Months
# Unknown string format: 2017 Feb- 2022 Dec
# Unknown string format: Sep 2013  Oct 2016
# Unknown string format: 2010- 2013
# Unknown string format: 2007-2010
# Unknown string format: 2004-2007
# Unknown string format: Feb `20
# Unknown string format: Jan `19
# Unknown string format: Apr `18
# Unknown string format: Sep `11
# Unknown string format: June `10
# Unknown string format: Feb `09
# Unknown string format: Aug `06
# Unknown string format: Since Sept19
# Unknown string format: Febuary 2022
# Unknown string format: "
# Unknown string format: "
# Unknown string format: "
# Unknown string format: "
# Unknown string format: Internship
# Unknown string format: April-June 2016
# bad month number 16; must be 1-12: 2015-16
# bad month number 17; must be 1-12: 2015-17
# bad month number 17; must be 1-12: 2015-17
# bad month number 14; must be 1-12: 2012-14
# bad month number 17; must be 1-12: 2015-17
# Unknown string format: Present
# Unknown string format: Led HR initiatives for a workforce of 150+ across 15+ states within the Asset Management vertical
# day is out of range for month: May 98, 2004
# Unknown string format: Aartl 2019
# day is out of range for month: Jan-00
# 'start_date'
# Unknown string format: 22ndJune 2021
# Unknown string format: 26thJuly 2021
# Unknown string format: APL 2013
# Unknown string format: East Feb 2019
# Unknown string format: East Aug 2015
# Unknown string format: West Bengal Oct 2012
# Unknown string format: East Jun 2009
# 'start_date'
# 'start_date'
# 'start_date'
# 'start_date'
# 'start_date'
# 'start_date'
# 'start_date'
# 'start_date'
# 'start_date'
# 'start_date'
# Unknown string format: 1& year
# Unknown string format: 06 Months
# Unknown string format: 06 Months
# Unknown string format: 4 & years
# Unknown string format: 4 & years
# Unknown string format: Board of Intermediate Education
# Unknown string format: Effective August 24, 2020
# Unknown string format: Effective July 1, 2022
# Unknown string format: Since Jan12
# Unknown string format: Aprrt from preprring timel monthl finrncirl strtements, budget preprrrtion rnd finrncirl forecrst, currentl working on internrtionrl business trrnsitions.
# Unknown string format: Jan19-Jrn 20
# Unknown string format: Sep14-Man15
# Unknown string format: Feb10-Jrn14
# Unknown string format: Apr06-Feb10
# Unknown string format: Jan05-Apr06
# Unknown string format: Apr04-Jan05
# Unknown string format: Total 7 years
# 'start_date'
# 'start_date'
# 'start_date'
# 'start_date'
# 'start_date'
# Unknown string format: 2 Months
# Unknown string format: NA
# Unknown string format: NA
# Unknown string format: NA
# Unknown string format: NA
# day is out of range for month: Aug 0
# day is out of range for month: November 00
# string indices must be integers
# string indices must be integers
# string indices must be integers
# string indices must be integers
# string indices must be integers
# string indices must be integers
# string indices must be integers
# string indices must be integers
# string indices must be integers
# string indices must be integers
# string indices must be integers
# string indices must be integers
# string indices must be integers
# string indices must be integers
# string indices must be integers
# string indices must be integers
# string indices must be integers
# string indices must be integers
# string indices must be integers
# string indices must be integers
# string indices must be integers
# string indices must be integers
# string indices must be integers
# string indices must be integers
# string indices must be integers
# string indices must be integers
# string indices must be integers
# string indices must be integers
# string indices must be integers
# string indices must be integers
# string indices must be integers
# string indices must be integers
# string indices must be integers
# string indices must be integers
# string indices must be integers
# string indices must be integers
# string indices must be integers
# string indices must be integers
# string indices must be integers
# string indices must be integers
# string indices must be integers
# string indices must be integers
# string indices must be integers
# string indices must be integers
# string indices must be integers
# string indices must be integers
# string indices must be integers
# string indices must be integers
# string indices must be integers
# string indices must be integers
# string indices must be integers
# string indices must be integers
# string indices must be integers
# string indices must be integers
# string indices must be integers
# string indices must be integers
# string indices must be integers
# string indices must be integers
# string indices must be integers
# string indices must be integers
# string indices must be integers
# string indices must be integers
# string indices must be integers
# string indices must be integers
# string indices must be integers
# string indices must be integers
# string indices must be integers
# string indices must be integers
# string indices must be integers
# string indices must be integers
# string indices must be integers
# string indices must be integers
# string indices must be integers
# string indices must be integers
# string indices must be integers
# string indices must be integers
# string indices must be integers
# Unknown string format: Alg-2003
# Unknown string format: Apl 1998
# Unknown string format: Present
# Unknown string format: TATA AIG LIFE INSURANCE
# Unknown string format: FromOct 2010
# Unknown string format: FromJune 2008
# Unknown string format: July-August 2023
# Unknown string format: Ahmedabad
# Unknown string format: 2020-2021
# Unknown string format: Current
# Unknown string format: Dee 2018
# day is out of range for month: Dec 00
# Unknown string format: Current
# Unknown string format: Aprii 2019
# day is out of range for month: Jan00
# bad month number 16; must be 1-12: 2015-16
# bad month number 18; must be 1-12: 2017-18
# bad month number 21; must be 1-12: 2020-21
# bad month number 20; must be 1-12: 2019-20
# bad month number 19; must be 1-12: 2018-19
# bad month number 20; must be 1-12: 2019-20
# bad month number 22; must be 1-12: 2021-22
# bad month number 22; must be 1-12: 2021-22
# bad month number 23; must be 1-12: 2022-23
# 'start_date'
# 'start_date'
# 'start_date'
# 'start_date'
# 'start_date'
# 'start_date'
# 'start_date'
# 'start_date'
# 'start_date'
# 'start_date'
# Unknown string format: 3 years Articleship under ICAI rules
# Unknown string format: Jan-03-June-2009
# Unknown string format: Juiy 2012
# day is out of range for month: Aug00
# day is out of range for month: Aug00
# Unknown string format: Before 2002
# Unknown string format: Aprii 2023
# Unknown string format: 2019-present
# Unknown string format: 2018-2019
# Unknown string format: 2017-2018
# Unknown string format: 2010-2017
# Unknown string format: 2006-2010
# Unknown string format: 2004-2006
# Unknown string format: 1999-2004
# Unknown string format: Aug,21- Present
# Unknown string format: Feb,2020- Aug-21
# Unknown string format: July,2018- Jan,2020
# Unknown string format: August,2016-July,2018
# Unknown string format: Oct2013-Aug 2016
# Unknown string format: 0394 to1112
# Unknown string format: 1994 to 1999
# Unknown string format: APTYN HOSPITALITY PVT. LTD.
# Unknown string format: Aprl16
# Unknown string format: Major Roles: Marketing, Sales
# Unknown string format: Present
# Unknown string format: Feb15-Dec15
# Unknown string format: Nov13- Sep14
# Unknown string format: Presently Working
# Unknown string format: Bangalore
# Unknown string format: Jun- 2017
# Unknown string format: May21-Present
# Unknown string format: Jun12-Apr15
# Unknown string format: Oct20-Apr21
# Unknown string format: May16-Apr20
# Unknown string format: Aug15-Sep15
# Unknown string format: 22 YEARS OF EXPERIENCE IN BUILDING BUSINESS ACROSS INDIA IN DIFFERENT INDUSTRIES IN SALES, OPERATIONS, KEY ACCOUNT MANAGEMENT UNILEVER, REVLON, 24 MANTRA ORGANIC AND KLAY. PEOPLE CHAMPION WITH COACHING STYLE.
# Unknown string format: 16.5+ Years
# Unknown string format: Internships
# Unknown string format: From Jul06
# Unknown string format: From May05
# Unknown string format: 1.5 Year
# Unknown string format: 2 Years
# Unknown string format: 2 Years
# Unknown string format: 2 Years
# Unknown string format: 2 Years
# Unknown string format: Mumbai, India
# Unknown string format: Mumbai, India
# 'start_date'
# 'start_date'
# 'start_date'
# 'start_date'
# 'start_date'
# day is out of range for month: Oct 00
# day is out of range for month: Oct 00
# Unknown string format: October 21-till Date
# Unknown string format: October 22-till Date
# Unknown string format: July- 2013
# Unknown string format: Pursuing
# Unknown string format: Jrn 2022
# Unknown string format: Jrn 2001
# Unknown string format: Jrn 1999
# Unknown string format: Present
# Unknown string format: Summer 2016
# Unknown string format: Overall facilities management - PAN India
# Unknown string format: SEP TEMB ER 2023
# Unknown string format: AUG US T 2014
# Unknown string format: OC TOB ER 2012
# Unknown string format: Led a 15-member team as a Go-to-Market/Help Content Subject Matter Expert for a technology giant.
# Unknown string format: Aprill 2017
# 'start_date'
# 'start_date'
# 'start_date'
# 'start_date'
# 'start_date'
# 'start_date'
# 'start_date'
# 'start_date'
# 'start_date'
# 'start_date'
# Unknown string format: Sept 2022- till present
# Unknown string format: Jan 2019 -Sept 2022
# Unknown string format: 2011-2012
# Unknown string format: 2012-2013
# Unknown string format: 2018-2020
# Unknown string format: Summer 2016
# 'start_date'
# 'start_date'
# 'start_date'
# 'start_date'
# 'start_date'
# Unknown string format: Currently working
# Unknown string format: Vadodara
# Unknown string format: Hotel Gaiety Palace
# Unknown string format: Symbiosis Institute of Management Studies
# Unknown string format: 3 Months
# day is out of range for month: Aug00
# Unknown string format: JUN - DEC 2018
# Unknown string format: MAR - APR 2018
# Unknown string format: MAY - JUN 2017
# Unknown string format: MAY - JUN 2017
# day is out of range for month: Oct 00
# day is out of range for month: Sep 00
# Unknown string format: Nov12Jan14
# Unknown string format: May11Nov12
# Unknown string format: 3 months
# Unknown string format: May-July04
# Unknown string format: Jan-July02
# Unknown string format: 2021-2022
# 'start_date'
# 'start_date'
# 'start_date'
# 'start_date'
# 'start_date'
# 'start_date'
# 'start_date'
# 'start_date'
# 'start_date'
# Unknown string format: 16thJan 2012
# Unknown string format: Jan to March 2015
# Unknown string format: May to June 2014
# Unknown string format: July 2022 (ongoing)
# Unknown string format: N/A
# Unknown string format: Noi 2012
# Unknown string format: ec 2009
# Unknown string format: Mar  Jul 2006
# Unknown string format: Septerber 2008
# 'start_date'
# 'start_date'
# 'start_date'
# 'start_date'
# 'start_date'
# 'start_date'
# Unknown string format: December20  Till Date
# Unknown string format: June'16- Sept18
# Unknown string format: Jan15 - May16
# Unknown string format: Nov 05  Aug 08
# Unknown string format: Sep 08  Dec14
# Unknown string format: Nov 00  May 03
# Unknown string format: Jun 03  Oct 05
# Unknown string format: May 98  Oct 00
# Unknown string format: Nov 00  May 03
# Unknown string format: Jan 2011-Aug ,2017
# Unknown string format: Oct 2010-sep 2011
# Unknown string format: Jan 2009 May 2010
# Unknown string format: Feb-Apr 2019
# Unknown string format: Now
# Unknown string format: 1 Year 3Months
# Unknown string format: 1 Year 3Months
# Unknown string format: 3 Years 6 Months
# Unknown string format: 6 Years
# Unknown string format: 9 Years
# day is out of range for month: Nov 00
# Unknown string format: May-Sept 2017
# 'start_date'
# 'start_date'
# 'start_date'
# 'start_date'
# Unknown string format: May - June 2001
# Unknown string format: Oct18- Till Date
# Unknown string format: July 15  Jan16
# Unknown string format: February16- October-18
# Unknown string format: 28thJune 2015
# Unknown string format: 24thNov, 2014
# Unknown string format: 1stNov 2012
# Unknown string format: 0 2 / 0 2 / 2 0 0 9
# Unknown string format: 2 0 / 0 6 / 2 0 0 8
# Unknown string format: 0 5 / 0 4 / 2 0 0 6
# Unknown string format: 0 2 / 0 6 / 2 0 0 3
# Unknown string format: 0 5 / 0 4 / 2 0 0 6
# Unknown string format: 0 5 / 0 4 / 2 0 0 6
# Unknown string format: 0 5 / 0 4 / 2 0 0 6
# Unknown string format: 0 5 / 0 4 / 2 0 0 6
# 'start_date'
# Unknown string format: Ont 2021
# Unknown string format: Led a multifaceted internship project encompassing operations in Electrical, Mechanical, Civil, Electronics, Metrology, and the Stores Function, with a specic focus on the Smart Host Microcontroller integration.
# 'start_date'
# 'start_date'
# 'start_date'
# 'start_date'
# 'start_date'
# 'start_date'
# 'start_date'
# 'start_date'
# 'start_date'
# 'start_date'
# Unknown string format: Mumbai, India
# Unknown string format: April-May 2018
# Unknown string format: May-Jun 2018
# bad month number 22; must be 1-12: 2021-22
# Unknown string format: 2 Years 5 Months (September 2014 - February 2017)
# Unknown string format: 11 Months (November 2012- October 2013)
# Unknown string format: 4 Years 2 Months (April 2006 - June 2010)
# 'start_date'
# 'start_date'
# 'start_date'
# 'start_date'
# 'start_date'
# 'start_date'
# 'start_date'
# 'start_date'
# Unknown string format: Current
# Unknown string format: Cleared Group 1 of CA Final after completing 3 years of CA Internship
# Unknown string format: Junle 2013
# Unknown string format: Junle 2007
# Unknown string format: Junle 2003
# Unknown string format: Junle 1999
# Unknown string format: Junle 1995
# Unknown string format: Aerocity, Airport Area New Delhi
# day is out of range for month: Jul00
# Unknown string format: 2016-2018
# Unknown string format: 2010-2014
# Unknown string format: 14 Years
# Unknown string format: 0 6 / 2 0 2 2
# Unknown string format: 0 1 / 2 0 1 9 - 0 6 / 2 0 2 2
# Unknown string format: 1 2 / 2 0 1 0 - 1 2 / 2 0 1 8
# Unknown string format: 1 1 / 2 0 0 7 - 1 2 / 2 0 1 0
# Unknown string format: 1 1 / 2 0 0 7 - 1 2 / 2 0 1 0
# Unknown string format: 6 months
# Unknown string format: 2011-2013
# Unknown string format: 2013-2015
# Unknown string format: 2008-2011
# Unknown string format: 2007-2008
# Unknown string format: 2005-2006
# Unknown string format: Current
# 'start_date'
# 'start_date'
# 'start_date'
# 'start_date'
# 'start_date'
# 'start_date'
# 'start_date'
# 'start_date'
# 'start_date'
# 'start_date'
# 'start_date'
# 'start_date'
# 'start_date'
# Unknown string format: Bangalore 2022 N 3ov 2023
# Unknown string format: Mar 2019 N an 2022
# Unknown string format: Mar 2019 N an 2022
# Unknown string format: May 2016 N Vct 2018
# Unknown string format: May 2016 N Vct 2018
# Unknown string format: National Semifinalist, Airtel i-Create
# Unknown string format: Jan-Aug 2016
# Unknown string format: Apr-Jun 2018
# Unknown string format: Jun-Aug 2015
# Unknown string format: Successful Start-up companies -Brand/Product Launches Handled:
# Unknown string format: Dec’19
# Unknown string format: Apr’19
# Unknown string format: Aug’18
# Unknown string format: Sep’14
# Unknown string format: Apr’12
# Unknown string format: Jan’08
# Unknown string format: Aug’07
# Unknown string format: Jan’06
# Unknown string format: Jan’03
# Unknown string format: Jun’01
# Unknown string format: Jul’96
# 'start_date'
# 'start_date'
# 'start_date'
# 'start_date'
# 'start_date'
# Unknown string format: Internship
# Unknown string format: Internship
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[58], line 8
#       6     month = int(es_wex['fromExpMonth'])
#       7     year = int(es_wex['fromExpYear'])
# ----> 8     start_time = datetime(year, month,1)
#       9     es_jobs.append(start_time)
#      11 try:
#
# ValueError: month must be in 1..12
