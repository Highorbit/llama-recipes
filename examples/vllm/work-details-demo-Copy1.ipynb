# %%
from vllm import LLM, SamplingParams
import numpy as np 
import pandas as pd 
import json 
import gradio as gr
from user_info import get_user_info
import ast, html, re

# %%
from huggingface_hub import login
login(token='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')
# Out:
# Token will not been saved to git credential helper. Pass `add_to_git_credential=True` if you want to set the git credential as well.
# Token is valid (permission: read).
# Your token has been saved to /home/ubuntu/.cache/huggingface/token
# Login successful

# %%
eval_df = pd.read_csv('../custom_data/iimjobs_eval_df.csv')

# %%
eval_df.head(10)
# Out:
#         id                                             resume  \
# 0  1447358  ROHAN\nAZAD\nI am a certified data scientist w...
# 1  1936688  P U N E E T G U P T A\nE-mail: puneet_mkgupta@...
# 2   690952  Nayana Rao (B.E, PGDSM-MIT, SPJIMR - Virginia ...
# 3  1394972  vz\nNITIN MISHRA\nBUSINESS HEAD\nOVERVIEW\n Ec...
# 4   950206  Anshul Garg\nCA, CPA(USA)\n+91-7982351846\nCaa...
# 5   541353  A Simple PDF File\nThis is a small demonstrati...
# 6  1711307  Smriti Goel Email:smritigoel.2016@gmail.com\nC...
# 7  1497250  BHAVIK DOSHI\n9909954045 bhavik.doshi@outlook....
# 8  2118031  Surendra Kota\nSummary\nSurendra is a Qualifed...
# 9   560988  Rahul Jauhari\nMobile: +91- 8175841628 ~\nE-Ma...
#
#                  current_designation  user_experience  \
# 0                       Data Analyst                6
# 1               Technical Specialist               13
# 2                Business consultant               12
# 3                      Business Head                5
# 4                    Manager Finance                7
# 5                            manager               31
# 6                    Product Manager                5
# 7  Consultant - Healthcare Solutions                7
# 8           Finance Business Partner               12
# 9   Assistant Manager Administration                8
#
#                                             keywords
# 0  Finance Analytics Excel Social_Media Leadershi...
# 1  Production Client SAP Testing Automation Team_...
# 2  Analysis Insurance Client Business_Process Com...
# 3  Sales Corporate Retail Planning Ecommerce Corp...
# 4  TAX Financial Audit Accountant Internal_Contro...
# 5                                                NaN
# 6  Strategy Sales Analysis Mobile_App Onboarding ...
# 7  Digital Commercial Analytics Client Pharma Res...
# 8  Financial Brand Operations Budgeting Marketing...
# 9  IT Technical_Support Maintenance Planning Fedo...

# %% [markdown]
# ### Download work-details model

# %%
sampling_params = SamplingParams(temperature=0, max_tokens=4096)
llm = LLM(model='lakshay/work-details')
# Out:
# INFO 01-24 10:55:10 llm_engine.py:73] Initializing an LLM engine with config: model='lakshay/work-details', tokenizer='lakshay/work-details', tokenizer_mode=auto, revision=None, tokenizer_revision=None, trust_remote_code=False, dtype=torch.float16, max_seq_len=4096, download_dir=None, load_format=auto, tensor_parallel_size=1, quantization=None, enforce_eager=False, seed=0)
# INFO 01-24 10:57:01 llm_engine.py:223] # GPU blocks: 814, # CPU blocks: 512
# INFO 01-24 10:57:04 model_runner.py:394] Capturing the model for CUDA graphs. This may lead to unexpected consequences if the model is not static. To run the model in eager mode, set 'enforce_eager=True' or use '--enforce-eager' in the CLI.
# INFO 01-24 10:57:10 model_runner.py:437] Graph capturing finished in 7 secs.

# %%
# Out:
#           id                                             resume  \
# 124  2376601  Page 1 of 2\nBhaskara Patnaik\nHrbpbhaskar2910...
# 54   2779291  Shiva Singh\nSouth Delhi, Delhi, India\nshivas...
# 374   395311  KARISHMA MANCHANDA\nEmail: karishmamanchanda.a...
# 342   654659  EDUCATIONAL QUALIFICATION\nCERTIFICATION\nWORK...
# 230  1127758  Anurag Gite Marketing Manager\nMumbai +91-8109...
# 134   566708  Email: gaurab.nitd@gmail.com Mobile: (+91) 702...
# 12    873595  Chartered Accountant\nVIKASH PATANGI\nI am a s...
# 332  1721767  Praveen V G\nVedanta Resources | MBA, IIM Calc...
# 271   118590  Natarajan Subramanian 54/ A23, Jeevan Bhima\nN...
# 76   2556184  SHARAD AGARWAL\nMBA (MARKETING &amp; HUMAN RES...
#
#                     current_designation  user_experience  \
# 124                 Asst Manager - HRBP               14
# 54   marketing and stratedgy consultant                5
# 374            Senior Associate Finance                8
# 342  AGM - Corporate and Sales Strategy                9
# 230                   Marketing manager                3
# 134                     Program Manager               15
# 12                   Finance Controller               12
# 332           Strategy & Growth manager                1
# 271            Associate Vice President               22
# 76                 Senior IT Consultant                2
#
#                                               keywords
# 124  HR Strategy Engineering Attrition Leadership B...
# 54   Planning Strategy Customer_Service Business_St...
# 374  Reporting Credit Financial Oracle Finance Oper...
# 342  Sales Real_Estate Financial Due_Diligence Tran...
# 230  Marketing Campaign Customer_Engagement HR Test...
# 134  Strategy Agile Strategic Sales Planning Financ...
# 12   R C TAX Financial Accounting Process_Improveme...
# 332  Strategy Sales Trading Digitization Emission F...
# 271  Financial Reporting Analysis Six_Sigma Client ...
# 76   Marketing Sales Client Warehousing Finance Acq...
# Traceback (most recent call last):
#   File "/home/ubuntu/infoedge/llama-recipes/env/lib/python3.10/site-packages/gradio/queueing.py", line 489, in call_prediction
#     output = await route_utils.call_process_api(
#   File "/home/ubuntu/infoedge/llama-recipes/env/lib/python3.10/site-packages/gradio/route_utils.py", line 232, in call_process_api
#     output = await app.get_blocks().process_api(
#   File "/home/ubuntu/infoedge/llama-recipes/env/lib/python3.10/site-packages/gradio/blocks.py", line 1561, in process_api
#     result = await self.call_function(
#   File "/home/ubuntu/infoedge/llama-recipes/env/lib/python3.10/site-packages/gradio/blocks.py", line 1179, in call_function
#     prediction = await anyio.to_thread.run_sync(
#   File "/home/ubuntu/infoedge/llama-recipes/env/lib/python3.10/site-packages/anyio/to_thread.py", line 33, in run_sync
#     return await get_asynclib().run_sync_in_worker_thread(
#   File "/home/ubuntu/infoedge/llama-recipes/env/lib/python3.10/site-packages/anyio/_backends/_asyncio.py", line 877, in run_sync_in_worker_thread
#     return await future
#   File "/home/ubuntu/infoedge/llama-recipes/env/lib/python3.10/site-packages/anyio/_backends/_asyncio.py", line 807, in run
#     result = context.run(func, *args)
#   File "/home/ubuntu/infoedge/llama-recipes/env/lib/python3.10/site-packages/gradio/utils.py", line 678, in wrapper
#     response = f(*args, **kwargs)
#   File "/tmp/ipykernel_1399/963100532.py", line 65, in get_response_from_model
#     eval_prompt = make_eval_prompt(resume_text)
#   File "/tmp/ipykernel_1399/963100532.py", line 33, in make_eval_prompt
#     eval_prompt = eval_prompt.format(resume_text=raw_text)
# UnboundLocalError: local variable 'eval_prompt' referenced before assignment

# %%
def convert_to_json(input_string):
    # Replace single quotes at the start and end of keys and values with double quotes
    # This regex specifically targets the start of keys/values and the end of keys/values
    corrected_string = re.sub(r"(\{|\,)\s*\'", r'\1 "', input_string)  # Start of key/value
    corrected_string = re.sub(r"\'\s*(\,|\})", r'" \1', corrected_string)  # End of key/value
    corrected_string = re.sub(r"\'\s*:", r'":', corrected_string)  # Key end
    corrected_string = re.sub(r":\s*\'", r': "', corrected_string)  # Value start

    try:
        # Convert the string to a valid JSON
        valid_json = json.loads(corrected_string)
        print(f'it worked!')
        return valid_json
    except json.JSONDecodeError as e:
        print(f'Error thrown in JSON converter is {e}')
        return input_string

def make_eval_prompt(raw_text):
    
    
    work_prompt = f'''
    You are an accurate agent working for a job platform. You will be given the raw 
    unstructured text of a user's resume, and the task is to extract only the following details about the 
    work experience of the user from the resume in a JSON style format: company name, designation, start date and the end date.
    Please provide the data in a concise and parseable JSON format. Ensure the JSON syntax is correct
    with proper use of double quotes, commas, and braces. Dates should be in "mm/yyyy" format

    This is the resume text:\n{{resume_text}}\n
    This is the output in the required_format:\n
    '''
    
    
    eval_prompt = work_prompt.format(resume_text=raw_text)

    return eval_prompt

def parse_user_work_ex(info_json):
    work_ex = []
    try:
        for x in info_json['professional_info'][0]:
            
            user_dict = {}
            exp_dict = x
        
            keys = ['id','designation','fromExpMonth','fromExpYear','toExpMonth','toExpYear'] 
        
            for k in keys:
                user_dict[k] = exp_dict[k]
                
            user_dict['company'] = exp_dict['organization']['name']
            work_ex.append(user_dict)
    except:
        return work_ex
            
    return work_ex



def get_response_from_model(user_id):

    es_output = get_user_info(user_id)
    resume_text = es_output['resume'][0]
    work_ex = parse_user_work_ex(es_output)
    if resume_text:
        eval_prompt = make_eval_prompt(resume_text)
    
    outputs = llm.generate(eval_prompt, sampling_params)
    out_text = outputs[0].outputs[0].text
    ot = html.unescape(out_text)
    generated_text = ot
    
    try:
        out_json = ast.literal_eval(generated_text)
        return json.dumps(out_json,indent=4), json.dumps(work_ex,indent=4)

    except Exception as e:
        print(f'couldnt JSONify this {e}')
        gt = convert_to_json(generated_text)
        return json.dumps(gt, indent=4), json.dumps(work_ex,indent=4)


demo = gr.Interface(
    fn=get_response_from_model,
    inputs=[gr.Textbox(label="UserID")],
    outputs=[gr.Textbox(label="LLM Output"),gr.Textbox(label="User Info from ElasticSearch")],
    allow_flagging="manual"
)

demo.launch(share=True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 82
#      78         gt = convert_to_json(generated_text)
#      79         return json.dumps(gt, indent=4), json.dumps(work_ex,indent=4)
# ---> 82 demo = gr.Interface(
#      83     fn=get_response_from_model,
#      84     inputs=[gr.Textbox(label="UserID")],
#      85     outputs=[gr.Textbox(label="LLM Output"),gr.Textbox(label="User Info from ElasticSearch")],
#      86     allow_flagging="manual"
#      87 )
#      89 demo.launch(share=True)
#
# NameError: name 'gr' is not defined
